# %%
# Py Code to play " KBC " game .
print("Welcome To KBC")
print("10 Questions To Change Your Life !!!")

# Function
print("*")
print("*")
def ask_question(question, options, correct_answer, points):
    print(question)

    for option, answer in options.items():
        print(f"{option}. {answer}")
    

    user_choice = input("Enter Your Choice (A/B/C/D): ").upper()
    print("*")
    print("*")
    if user_choice == correct_answer:
        print(f"Correct Answer! You have earned {points} points!")
        print("*")
     
        print("Next Question is")
    
        print("*")
        return True
    else:
        print("Wrong Answer. Game Over.")
        print(f"Earned Points are : {total_points}")
        return False


# List Of Questions in the game
questions = [
    {
        "question": 'Question No 1 : What is the acronym "AI" typically stand for in the context of artificial intelligence? \nOptions Are : ',
        "options": {
            "A": "Advanced Intelligence",
            "B": "Artificial Insight",
            "C": "Artificial Intelligence",
            "D": "Automated Information"
        },
        "correct_answer": "C",  # correct answers
        "points": 1             # reward
    },
    {
        "question": "Question No 2 : Which programming language is often used for machine learning and deep learning? \nOptions Are : ",
        "options": {
            "A": "Java",
            "B": "C++",
            "C": "Python",
            "D": "Ruby"
        },
        "correct_answer": "C",
        "points": 2
    },
    {
        "question": "Question No 3 : What is the primary goal of unsupervised machine learning? \nOptions Are : ",
        "options": {
            "A": "Classification",
            "B": "Regression",
            "C": "Clustering",
            "D": "Reinforcement Learning"
        },
        "correct_answer": "C",
        "points": 3
    },
    {
        "question": 'Question No 4 : In natural language processing, what does the term "NLP" stand for? \nOptions Are : ',
        "options": {
            "A": "Natural Language Processing",
            "B": "Neural Language Programming",
            "C": "Natural Linguistic Processing",
            "D": "Neural Learning Process"
        },
        "correct_answer": "A",
        "points": 4
    },
    {
        "question": "Question No 5 : Which machine learning algorithm is commonly used for image recognition and computer vision tasks? \nOptions Are : ",
        "options": {
            "A": "Linear Regression",
            "B": "Support Vector Machine",
            "C": "Convolutional Neural Network",
            "D": "K-Means Clustering"
        },
        "correct_answer": "C",
        "points": 5
    },
    {
        "question": "Question No 6 : What is the primary function of a Recurrent Neural Network (RNN) in deep learning? \nOptions Are : ",
        "options": {
            "A": "Image segmentation",
            "B": "Text classification",
            "C": "Sequence modeling",
            "D": "Reinforcement learning"
        },
        "correct_answer": "C",
        "points": 6
    },
    {
        "question": 'Question No 7 : What does the term "overfitting" mean in the context of machine learning? \nOptions Are : ',
        "options": {
            "A": "The model performs well on the test data.",
            "B": "The model generalizes well to new data.",
            "C": "The model fits the training data too closely, potentially resulting in poor performance on new data. \nOptions Are : ",
            "D": "The model is undertrained and lacks complexity."
        },
        "correct_answer": "C",
        "points": 7
    },
    {
        "question": 'Question No 8 : In reinforcement learning, what is an "agent"? \nOptions Are : ',
        "options": {
            "A": "A computer program that designs neural networks.",
            "B": "A component that preprocesses raw data.",
            "C": "A learner or decision-maker that interacts with an environment",
            "D": "A specialized hardware device."
        },
        "correct_answer": "C",
        "points": 8
    },
    {
        "question": 'Question No 9 : What is the primary objective of "transfer learning" in deep learning? \nOptions Are : ',
        "options": {
            "A": "Training models from scratch for every new task.",
            "B": "Leveraging knowledge gained from one task to improve learning on a related task.",
            "C": "Sharing pre-trained models publicly.",
            "D": "Combining multiple machine learning algorithms."
        },
        "correct_answer": "B",
        "points": 9
    },
    {
        "question": "Question No 10 : Which deep learning framework is known for its use in building and training neural networks for image recognition, computer vision, and natural language processing? \nOptions Are : ",
        "options": {
            "A": "TensorFlow",
            "B": "PyTorch",
            "C": "Caffe",
            "D": "Keras"
        },
        "correct_answer": "D",
        "points": 10
    },
]

total_points = 0
game_over = False

# Iterate through the questions and ask each one
for question in questions:
    if ask_question(question["question"], question["options"], question["correct_answer"], question["points"]):
        total_points += question["points"]
    else:
        game_over = True
        break

if not game_over:
    print(f"Congratulations! You've completed all the questions. Total points: {total_points}")
# Out:
# Welcome To KBC
# 10 Questions To Change Your Life !!!
# *
# *
# Question No 1 : What is the acronym "AI" typically stand for in the context of artificial intelligence?
# Options Are :
# A. Advanced Intelligence
# B. Artificial Insight
# C. Artificial Intelligence
# D. Automated Information
# Enter Your Choice (A/B/C/D): C
# *
# *
# Correct Answer! You have earned 1 points!
# *
# Next Question is
# *
# Question No 2 : Which programming language is often used for machine learning and deep learning?
# Options Are :
# A. Java
# B. C++
# C. Python
# D. Ruby
# Enter Your Choice (A/B/C/D): C
# *
# *
# Correct Answer! You have earned 2 points!
# *
# Next Question is
# *
# Question No 3 : What is the primary goal of unsupervised machine learning?
# Options Are :
# A. Classification
# B. Regression
# C. Clustering
# D. Reinforcement Learning
# Enter Your Choice (A/B/C/D): A
# *
# *
# Wrong Answer. Game Over.
# Earned Points are : 3
